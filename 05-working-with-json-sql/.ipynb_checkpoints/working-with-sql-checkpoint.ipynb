# %%
import pandas as pd

# %% [markdown]
# # 1. For MYSQL

# %%
# !pip install mysql.connector
# Out:
# Requirement already satisfied: mysql.connector in C:\Users\tariq_6eqkbl7\anaconda3\Lib\site-packages (2.2.9)

# %%
import mysql.connector

# %%
mysql.connector.connect(host='localhost', user='root', password='', database='world')

# %% [markdown]
# # 2. For PostgreSQL

# %%
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in C:\Users\tariq_6eqkbl7\anaconda3\Lib\site-packages (2.9.12)

# %%
import psycopg2

# %%
connection = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="node",
    database="expense_tracker",
    port=5432
)

# %%
df = pd.read_sql_query("SELECT * FROM users WHERE role = 'user'", connection)
df
# Out:
# C:\Users\tariq_6eqkbl7\AppData\Local\Temp\ipykernel_432\2359735917.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM users WHERE role = 'user'", connection)
#    id   name                    email  \
# 0   2  Spike  spikenoob1110@gmail.com
#
#                                             password  role  is_active  \
# 0  $2b$10$9UlQsPCdSvWlqC4wDiY7xuF5qItl7L/iclP75S2...  user       True
#
#                   created_at
# 0 2026-07-20 22:47:19.625812
